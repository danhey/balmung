# %%
import numpy as np
from balmung import Balmung

# %%
times, mags = np.loadtxt('E:/lc/appended_8,9/kic9651065_appended-msMAP_Q99_llc.txt', usecols=(0,1)).T

# %%
bm = Balmung(times, mags)

# %% [markdown]
# Checking the original periodogram -

# %%
bm.plot()

# %% [markdown]
# Let's prewhiten freqs between 15 and 24

# %%
bm.run(steps=100, fmin=15, fmax=24)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:25<00:00,  3.88it/s]

# %%
bm.plot()

# %% [markdown]
# neato
